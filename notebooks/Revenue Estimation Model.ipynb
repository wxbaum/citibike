# %% [markdown]
# # Citibike Revenue Estimation Model
#
# In this notebook we'll run through the process of building a machine
# learning model to estimate revenue generated by the Citibike system on a
# given day. We'll use a combination of time-series modeling, and feature
# engineering around the impacts of external "systems" such as weather.
